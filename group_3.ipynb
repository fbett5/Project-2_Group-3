# %% [markdown]
# <a href="https://colab.research.google.com/github/fbett5/Project-2_Group-3/blob/main/group_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Automobile_data.csv')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
#Filling missing values with medians of the columns
#df2 = df.fillna(df.median())

# %%
df2.head()
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
df2.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
final_df = df2.drop(columns='normalized-losses', inplace= False)

# %%
# create dymmy variables
pd.get_dummies(final_df, columns= ['fuel-type', 'drive-wheels', 'engine-location',
                                   'wheel-base','engine-type', 'num-of-cylinders',
                                   'aspiration']).drop(['make', 'num-of-doors','body-style'], 
                                                       axis =1, inplace = False)
# Out:
#      symboling  length  ...  aspiration_std  aspiration_turbo
# 0            3   168.8  ...               1                 0
# 1            3   168.8  ...               1                 0
# 2            1   171.2  ...               1                 0
# 3            2   176.6  ...               1                 0
# 4            2   176.6  ...               1                 0
# ..         ...     ...  ...             ...               ...
# 200         -1   188.8  ...               1                 0
# 201         -1   188.8  ...               0                 1
# 202         -1   188.8  ...               1                 0
# 203         -1   188.8  ...               0                 1
# 204         -1   188.8  ...               0                 1
#
# [205 rows x 91 columns]
